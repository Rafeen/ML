# %%
import os
import numpy as np
from sklearn import preprocessing, neighbors
from sklearn.model_selection import train_test_split 
from sklearn import metrics
import pandas as pd

# for min_max scaling
from sklearn.preprocessing import MinMaxScaler

# for Box-Cox Transformation
from scipy import stats

# %% [markdown]
# ### load data

# %%
df = pd.read_csv('dataset/cleaned_data.csv')
df.head()
# Out:
#    Unnamed: 0  age  gender  limit_diet  gain_10kg  gain_lose_3kg  \
# 0           0   59       1           0          0              0
# 1           1   60       1           1          1              0
# 2           2   58       1           1          1              1
# 3           3   50       2           1          0              0
# 4           4   56       1           1          0              0
#
#    eat_2h_sleep  soft_drink  fast_food  skip_breakfast  ...  bp_sys  bp_dia  \
# 0             0           0          0               1  ...     138      78
# 1             1           0          0               0  ...     128      67
# 2             1           0          0               0  ...     140      81
# 3             1           1          0               0  ...     102      65
# 4             1           0          0               0  ...     155      98
#
#    blood_glucose  blood_hemoglobin  urinary_glucose  urinary_protein  \
# 0          234.0               NaN                0                0
# 1           93.6               NaN                0                0
# 2          133.2               NaN                0                0
# 3           75.6              10.9                0                0
# 4          223.2               NaN                0                0
#
#    pulse_rate  uric_acid  health_status    bmi
# 0          94        4.3              3  20.85
# 1          62        5.8              2  27.48
# 2          60        7.0              3  31.12
# 3          82        3.6              2  22.05
# 4          92        5.0              3  25.35
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Data Processing and cleaning

# %%
# replacing missing parameters with a null
df.replace('?', np.nan , inplace=True)
df.isna().sum()

# replacing missing null with a value -9999
df.replace(np.nan, -99999, inplace=True)

# %%
# seperating features and calss
features = df.drop(['health_status', 'blood_hemoglobin'], axis=1)
label = df['health_status']

# %%
#data scaling

scaler = MinMaxScaler()
scaler.fit(data)
scaled_data = scaler.transform(data)

# plot both together to compare
fig, ax=plt.subplots(1,2)
sns.distplot(data, ax=ax[0])
ax[0].set_title("Original Data")
sns.distplot(scaled_data, ax=ax[1])
ax[1].set_title("Scaled data")

# %%
# splitting training and test data
x_train, x_test, y_train, y_test = train_test_split(features, label, test_size=0.1, random_state=2)

# %%
# printing the shape of data
print(features.shape, x_train.shape, x_test.shape)
# Out:
# (50, 27) (45, 27) (5, 27)

# %% [markdown]
# ### Loading Classifier
# #### K nearest neighbor

# %%
clf = neighbors.KNeighborsClassifier()

# %%
# training the classifier
clf.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# getting accuracy score for training data
accuracy = clf.score(x_test, y_test)
print(round(accuracy*100,2),'%')
# Out:
# 60.0 %

# %%
features.head()
# Out:
#    Unnamed: 0  age  gender  limit_diet  gain_10kg  gain_lose_3kg  \
# 0           0   59       1           0          0              0
# 1           1   60       1           1          1              0
# 2           2   58       1           1          1              1
# 3           3   50       2           1          0              0
# 4           4   56       1           1          0              0
#
#    eat_2h_sleep  soft_drink  fast_food  skip_breakfast  ...  body_temperature  \
# 0             0           0          0               1  ...             95.00
# 1             1           0          0               0  ...             96.26
# 2             1           0          0               0  ...             95.00
# 3             1           1          0               0  ...             97.52
# 4             1           0          0               0  ...             96.44
#
#    spo2  bp_sys  bp_dia  blood_glucose  urinary_glucose  urinary_protein  \
# 0    96     138      78          234.0                0                0
# 1    96     128      67           93.6                0                0
# 2    96     140      81          133.2                0                0
# 3    99     102      65           75.6                0                0
# 4    96     155      98          223.2                0                0
#
#    pulse_rate  uric_acid    bmi
# 0          94        4.3  20.85
# 1          62        5.8  27.48
# 2          60        7.0  31.12
# 3          82        3.6  22.05
# 4          92        5.0  25.35
#
# [5 rows x 27 columns]
