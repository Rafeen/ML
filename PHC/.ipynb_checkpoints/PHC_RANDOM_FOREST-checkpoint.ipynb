# %% [markdown]
# # PHC status Prediction

# %%
#### Importing Dependenceis

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score

# %% [markdown]
# #### Data Importing

# %%
#loading the dataset
df = pd.read_csv('dataset/clean_sample_data.csv', index_col=0)
df.head()
# Out:
#    Age   Gender  Height  Weight    BMI  Waist  Hip  Waist/Hip Ratio  \
# 0    59       1   159.0    52.7  20.85   85.0   80             1.06
# 1    60       1   164.0    73.9  27.48   95.0   99             0.96
# 2    58       1   164.0    83.7  31.12  102.0  103             0.99
# 3    50       0   143.0    45.1  22.05   76.0   89             0.85
# 4    56       1   160.0    64.9  25.35   87.0   91             0.96
#
#    BodyTemperature  SpO2  BloodPressure(sys)  BloodPressure(dia)  \
# 0            95.00     1                   1                   1
# 1            96.26     1                   1                   1
# 2            95.00     1                   1                   0
# 3            97.52     1                   1                   1
# 4            96.44     1                   1                   0
#
#    BloodGlucose  PulseRate  BloodUricAcid  Color  pressure
# 0         234.0         94            4.3      3         1
# 1          93.6         62            5.8      2         1
# 2         133.2         60            7.0      3         0
# 3          75.6         82            3.6      2         1
# 4         223.2         92            5.0      3         0

# %%
# numbers of rows and columns
df.shape
# Out:
# (271, 17)

# %%
# checking for missing values
df.isnull().sum()
# Out:
# Age                   0
# Gender                0
# Height                0
# Weight                0
# BMI                   0
# Waist                 0
# Hip                   0
# Waist/Hip Ratio       0
# BodyTemperature       0
# SpO2                  0
# BloodPressure(sys)    0
# BloodPressure(dia)    0
# BloodGlucose          0
# PulseRate             0
# BloodUricAcid         0
# Color                 0
# pressure              0
# dtype: int64

# %% [markdown]
# ### Data analysis and visualization

# %%
# statistical measures of the dataset
df.describe()
# Out:
#              Age       Gender      Height      Weight         BMI       Waist  \
# count  271.000000  271.000000  271.000000  271.000000  271.000000  271.000000
# mean    49.605166    0.830258  163.051661   67.521402   25.367011   90.242066
# std      7.390372    0.376100    7.442564   10.056410    3.201135    7.791515
# min     34.000000    0.000000  140.000000   44.200000   18.390000   63.600000
# 25%     44.000000    1.000000  158.000000   61.250000   23.265000   85.000000
# 50%     50.000000    1.000000  164.000000   67.500000   25.150000   90.000000
# 75%     55.000000    1.000000  168.000000   73.400000   26.860000   95.000000
# max     77.000000    1.000000  184.000000  114.400000   40.530000  118.000000
#
#               Hip  Waist/Hip Ratio  BodyTemperature        SpO2  \
# count  271.000000       271.000000       271.000000  271.000000
# mean    94.538745         0.954834        95.842214    0.992620
# std      6.289716         0.050727         3.728073    0.085748
# min     80.000000         0.640000        37.580000    0.000000
# 25%     91.000000         0.930000        95.360000    1.000000
# 50%     94.000000         0.960000        96.260000    1.000000
# 75%     98.000000         0.990000        96.800000    1.000000
# max    127.000000         1.110000        98.420000    1.000000
#
#        BloodPressure(sys)  BloodPressure(dia)  BloodGlucose   PulseRate  \
# count               271.0          271.000000    271.000000  271.000000
# mean                  1.0            0.435424    128.012546   80.269373
# std                   0.0            0.496730     56.911955   11.656080
# min                   1.0            0.000000     66.600000   51.000000
# 25%                   1.0            0.000000     90.000000   72.000000
# 50%                   1.0            0.000000    111.600000   80.000000
# 75%                   1.0            1.000000    142.200000   88.000000
# max                   1.0            1.000000    392.400000  123.000000
#
#        BloodUricAcid       Color    pressure
# count     271.000000  271.000000  271.000000
# mean        6.621771    2.937269    0.435424
# std         1.533746    0.755066    0.496730
# min         3.100000    1.000000    0.000000
# 25%         5.700000    2.000000    0.000000
# 50%         6.600000    3.000000    0.000000
# 75%         7.600000    3.000000    1.000000
# max        11.000000    4.000000    1.000000

# %%
# number of values for each values
sns.catplot(x='Color', data=df, kind = 'count', palette={1:"green", 2:"yellow", 3:'orange', 4:'red'})

# %% [markdown]
# #### Correlation
#
#     1.Positive Correlation
#     2.Negative COrrelation

# %%
correlation = df.corr()

# constructing a heatmap to undestand the correlation between the columns
plt.figure(figsize=(15,15))
sns.heatmap(correlation, cbar=True, square=True, fmt='.1f', annot=True, annot_kws={'size':12}, cmap = 'OrRd')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Data Preprocessing

# %%
# seperate the data and label

df = df.dropna()
# data = df.drop(['Color', 'blood_hemoglobin'], axis=1)
data = df.drop(['Color', 'Height', 'Weight', 'Hip', 'BloodPressure(sys)', 'BloodPressure(dia)'], axis=1)

label = df.Color
print(data)
# Out:
#      Age   Gender    BMI  Waist  Waist/Hip Ratio  BodyTemperature  SpO2  \
# 0      59       1  20.85   85.0             1.06            95.00     1
# 1      60       1  27.48   95.0             0.96            96.26     1
# 2      58       1  31.12  102.0             0.99            95.00     1
# 3      50       0  22.05   76.0             0.85            97.52     1
# 4      56       1  25.35   87.0             0.96            96.44     1
# ..    ...     ...    ...    ...              ...              ...   ...
# 266    59       1  22.68   90.0             0.98            93.56     1
# 267    50       0  22.55   89.0             1.00            97.34     1
# 268    58       0  22.90   84.0             0.93            95.00     1
# 269    50       0  22.81   78.0             0.92            96.26     1
# 270    56       1  23.01   88.0             0.93            96.26     1
#
#      BloodGlucose  PulseRate  BloodUricAcid  pressure
# 0           234.0         94            4.3         1
# 1            93.6         62            5.8         1
# 2           133.2         60            7.0         0
# 3            75.6         82            3.6         1
# 4           223.2         92            5.0         0
# ..            ...        ...            ...       ...
# 266          86.4         97            7.6         0
# 267         306.0         80            3.6         1
# 268         124.2         77            5.2         0
# 269         286.2         82            3.7         1
# 270         118.8         77            7.7         0
#
# [271 rows x 11 columns]

# %% [markdown]
# #### Label Binarization

# %% [markdown]
# #### Training and Test Data

# %%
# seperating traing and test data
data_train, data_test, label_train, label_test = train_test_split(data, label, test_size=0.2, random_state=2)

print(data.shape, data_train.shape, data_test.shape)
# Out:
# (271, 11) (216, 11) (55, 11)

# %% [markdown]
# ### Model Training
# #### Random Forest  Classifier

# %%
model = RandomForestClassifier()

model.fit(data_train, label_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# ### Model Evaluation
# #### Accuracy Score

# %%
# accuracy test on data
data_test_prediction = model.predict(data_test)
test_data_accuracy = accuracy_score(data_test_prediction, label_test)

print('Accuracy : ', test_data_accuracy* 100)
# Out:
# Accuracy :  69.0909090909091

# %%
### Building the predictive System

# input_data = (6.9,0.52,0.25,2.6,0.081,10.0,37.0,0.99685,3.46,0.5,11.0)
# input_data = np.asarray(input_data)
# input_data = input_data.reshape(1, -1)
# prediction = model.predict(input_data)
# if prediction[0]==1:
#     print("Good Quality")
# else:
#     print("Poor Quality")
