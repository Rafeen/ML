# %%
import os
import numpy as np
from sklearn import preprocessing, neighbors
from sklearn.model_selection import train_test_split 
from sklearn import metrics
import pandas as pd

# %%
df = pd.read_csv('dataset/raw_data.csv')

# %%
df.head(6).sleep_habit
# Out:
# 0        2. Rarely (1-5 days per month)
# 1    3. Sometimes (6-10 days per month)
# 2        2. Rarely (1-5 days per month)
# 3                              1. Never
# 4                              1. Never
# 5                              1. Never
# Name: sleep_habit, dtype: object

# %%
df.shape
# Out:
# (50, 33)

# %% [markdown]
# ### removing unnecessary columns

# %%
data = df.drop( columns = ['education', 'marital_status', 'monthly_income'], axis=1)

# %% [markdown]
# ### Changing string value to numerical values

# %%
data.replace({'Yes': 1, 'No': 0, '1.  No': 0, '2. Yes': 1, '1. No':0}, inplace=True)
data.replace({'Male': 1, 'Female': 2}, inplace=True)
data.replace({'-': 0, '+': 1}, inplace=True)
data.replace({'1. More than 1 hour per day': 1, '2. Less than 1 hour per day': 2, '3. Don壽猼 go outside for walk':3}, inplace=True)
data.replace({'1. Never': 1, '2. Rarely (1-5 days per month)': 2, '3. Sometimes (6-10 days per month)':3}, inplace=True)
data['blood_glucose'] = data['blood_glucose'].str.replace(r"\(.*\)","")

# %%
data.head(5)
# Out:
#    age  gender  limit_diet gain_10kg gain_lose_3kg  eat_2h_sleep soft_drink  \
# 0   59       1           0         0             0             0          0
# 1   60       1           1         1             0             1          0
# 2   58       1           1         1             1             1          0
# 3   50       2           1         0             0             1          1
# 4   56       1           1         0             0             1          0
#
#    fast_food  skip_breakfast eat_faster  ...  spo2  bp_sys bp_dia  \
# 0          0               1          0  ...    96     138     78
# 1          0               0          1  ...    96     128     67
# 2          0               0          1  ...    96     140     81
# 3          0               0          0  ...    99     102     65
# 4          0               0          1  ...    96     155     98
#
#   blood_glucose blood_hemoglobin  urinary_glucose  urinary_protein  \
# 0          234               NaN                0                0
# 1         93.6               NaN                0                0
# 2        133.2               NaN                0                0
# 3         75.6              10.9                0                0
# 4        223.2               NaN                0                0
#
#    pulse_rate  uric_acid  health_status
# 0          94        4.3              3
# 1          62        5.8              2
# 2          60        7.0              3
# 3          82        3.6              2
# 4          92        5.0              3
#
# [5 rows x 30 columns]

# %%
data.iloc[:10,:15]
# Out:
#    age  gender  limit_diet gain_10kg gain_lose_3kg  eat_2h_sleep soft_drink  \
# 0   59       1           0         0             0             0          0
# 1   60       1           1         1             0             1          0
# 2   58       1           1         1             1             1          0
# 3   50       2           1         0             0             1          1
# 4   56       1           1         0             0             1          0
# 5   59       1           1         0             0             1          0
# 6   59       1           1         0             0             0          0
# 7   57       1           1         0             1             1          0
# 8   45       1           0         1             0             1          1
# 9   58       1           1         0             0             1          0
#
#    fast_food  skip_breakfast eat_faster  walking_habit  physical_activity  \
# 0          0               1          0              2                  1
# 1          0               0          1              3                  1
# 2          0               0          1              1                  1
# 3          0               0          0              1                  1
# 4          0               0          1              2                  1
# 5          0               0          0              1                  1
# 6          0               0          0              1                  1
# 7          0               0          0              1                  1
# 8          0               0          1              1                  1
# 9          0               0          1              1                  1
#
#   walk_faster                         sleep_habit  \
# 0           1      2. Rarely (1-5 days per month)
# 1           0  3. Sometimes (6-10 days per month)
# 2           0      2. Rarely (1-5 days per month)
# 3           1                            1. Never
# 4           1                            1. Never
# 5           0                            1. Never
# 6           0                            1. Never
# 7           1                            1. Never
# 8           0      2. Rarely (1-5 days per month)
# 9           1      2. Rarely (1-5 days per month)
#
#                         stop_activity
# 0      2. Rarely (1-5 days per month)
# 1                            1. Never
# 2      2. Rarely (1-5 days per month)
# 3                            1. Never
# 4                            1. Never
# 5  3. Sometimes (6-10 days per month)
# 6                            1. Never
# 7                            1. Never
# 8      2. Rarely (1-5 days per month)
# 9      2. Rarely (1-5 days per month)
