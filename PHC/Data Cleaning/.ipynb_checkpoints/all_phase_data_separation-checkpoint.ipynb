# %% [markdown]
# ### Importing Dependencies

# %%
import os
import numpy as np
from sklearn import preprocessing, neighbors
from sklearn.model_selection import train_test_split 
from sklearn import metrics
import pandas as pd

# plotting modules
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data preview and shape

# %%
df = pd.read_excel('../dataset/all_phase_data.xlsx')

# %%
df.head(5)
# Out:
#     SL  Bar code Id  Age   Gender  Company Name 1. What is your occupation?  \
# 0  215   1000236740    56  Female  Grameen Bank                 Autonomous
# 1  116   1001011776    51  Female  Grameen Bank                  Autonomous
# 2   39   1001014480    60    Male  Grameen Bank                  Autonomous
# 3   52   1001014482    54    Male  Grameen Bank                  Autonomous
# 4   75   1000898321    55    Male  Grameen Bank                  Autonomous
#
#       2. What education did you complete? 3. Can you read Bangla?  \
# 0  7. Higher (Master or Doctor) completed                  3. Yes
# 1                4. High school completed                  3. Yes
# 2  7. Higher (Master or Doctor) completed                  3. Yes
# 3           3. Secondary school completed                  3. Yes
# 4         6. College/University completed                  3. Yes
#
#          4. What is your marital status?  \
# 0  2. Current married or living together
# 1  2. Current married or living together
# 2  2. Current married or living together
# 3  2. Current married or living together
# 4  2. Current married or living together
#
#   5. What is your monthly family expenditure?  ...  \
# 0                      5. Taka 50,001 or more  ...
# 1                      5. Taka 50,001 or more  ...
# 2                      5. Taka 50,001 or more  ...
# 3                       4. Taka 20,001-50,000  ...
# 4                      5. Taka 50,001 or more  ...
#
#   5-38. PHC system is workable to prevent NCD diseases..2  \
# 0                                                5.0
# 1                                                5.0
# 2                                                5.0
# 3                                                5.0
# 4                                                5.0
#
#   5-39. Using PHC system is a good idea..2  \
# 0                                      5.0
# 1                                      5.0
# 2                                      5.0
# 3                                      5.0
# 4                                      5.0
#
#   5-40. I feel good to receive PHC service..2  \
# 0                                         5.0
# 1                                         5.0
# 2                                         5.0
# 3                                         5.0
# 4                                         5.0
#
#   5-41. I intend to use PHC system in the future..2  \
# 0                                               5.0
# 1                                               5.0
# 2                                               5.0
# 3                                               5.0
# 4                                               5.0
#
#   5-42. If PHC system is available, I will always use it..2  \
# 0                                                5.0
# 1                                                4.0
# 2                                                5.0
# 3                                                5.0
# 4                                                5.0
#
#   5-43. It is worth to receive PHC service..2  \
# 0                                         5.0
# 1                                         4.0
# 2                                         5.0
# 3                                         4.0
# 4                                         5.0
#
#   5-44. PHC system is a pleasant experience..2  \
# 0                                          4.0
# 1                                          3.0
# 2                                          5.0
# 3                                          3.0
# 4                                          4.0
#
#   5-45. I spend time to know about PHC system..2  \
# 0                                            4.0
# 1                                            1.0
# 2                                            3.0
# 3                                            1.0
# 4                                            2.0
#
#   5-46. Using PHC system causes many advantages..2  \
# 0                                              5.0
# 1                                              4.0
# 2                                              5.0
# 3                                              4.0
# 4                                              4.0
#
#   5-47. I like to use PHC system..2
# 0                               5.0
# 1                               5.0
# 2                               5.0
# 3                               4.0
# 4                               4.0
#
# [5 rows x 286 columns]

# %%
cmn = df[['SL','Bar code Id', 'Age ', 'Gender']]

data = df.drop(columns = ['SL', 'Bar code Id', 'Age ', 'Gender', 'Company Name', 'Blood Hemoglobin Color-1', 'Blood Hemoglobin-1'], axis =1)
# urinary_glucose
data.replace({'-': 0, '++': 1,}, inplace=True)

#unirary_protein

data.replace({'+': 1,}, inplace=True)

columns = list(data.columns)
print(*columns, sep = '\n')
# Out:
# 1. What is your occupation?
# 2. What education did you complete?
# 3. Can you read Bangla?
# 4. What is your marital status?
# 5. What is your monthly family expenditure?
# 6. Have you tried to limit any of the following things in your diet in the past 30 days? Have you tried to limit the amount of [READ ITEM] in your diet, yes or no?
# 7. Have you gained over 10 kg weight after the age of 20?
# 8. Have you gained or lost over 3 kg weight in the last one year?
# 9. Do you eat dinner within 2 hours before bedtime three or more times a week?
# 10. Do you drink sugar contained drinks (Coke, Fanta, Soda, Fruit Juice, other Sweet/Sugar contained drinks) three or more times a week?
# 11. Do you eat fast foods such as Pizza, Hamburger, Deep Fried Foods (e.g. Singara, Samosa, Moglai Parata, etc.) three or more time a week?
# 12. Do you skip breakfast three or more times a week?
# 13. Do you eat faster than others in your similar age and sex?
# 14. Do you want to improve your eating habits (less sugar, less fat, less calories, etc.) to be more healthy?
# 15. In the past 30 days, on an average how long did you usually walk outside per day? (walking outside besides other daily works such as agricultural, farming, or cleaning).
# 16. In the past 30 days, did you do any types of physical activities at least for 10 minutes continuously?(Multiple choices)
# 17. Do you walk faster than other people of your same age and sex?
# 18. Do you want to improve your physical activity (exercise) habits to be healthier?
# 19. In the last one month, how often you could not sleep properly at night?
# 20. In the last one month, how often you had to stop doing your usual activities (work, school or any other job) due to stress, depression, anxiety, or sadness?
# 21. What do you do when you are stressed or depressed?
# 22. What are the cause of your stress or depression?
# 23. How often do you brush your teeth every day?
# 24. Do you brush your teeth before you go to sleep at night?
# 25. What do you usually use for your brushing?
# 26. Have you visited any dental clinic or dentist in the last 6 months?
# 27. Do you have pain in your teeth, jaw or any parts in your mouth? (Multiple choices)
# 28. How many teeth have you lost?
# 29. Do you have any vision difficulties seeing or reading with your eyes?
# 30. Do you have any eye related diseases?
# Height-1
# Weight-1
# BMI-1
# BMI Color-1
# Waist-1
# Waist Color-1
# Hip-1
# Waist/Hip Ratio-1
# Waist/Hip Ratio Color-1
# Body Temperature-1
# Body Temperature Color-1
# SpO2-1
# SpO2 Color-1
# Blood Pressure(sys)-1
# Blood Pressure(sys) Color-1
# Blood Pressure(dia)-1
# Blood Pressure(dia) Color-1
# Blood Glucose-1
# Blood Glucose Color-1
# Urinary Glucose-1
# Urinary Glucose Color-1
# Urinary Protein-1
# Urinary Protein Color-1
# Pulse Rate-1
# Pulse Rate Color-1
# Arrhythmia-1
# Arrhythmia Color-1
# Blood uric acid-1
# Blood uric acid Color-1
# Color-1
# 1. Have you ever had any of following health check-up?(Multiple choice)
# 2. How satisfied about todayâ€™s health check-up?
# 3. Which health check-up services are you most interested in?(Multiple choice)
# 4. What additional services (besides health check-up services) do you want or do you need?  (Multiple choice)
# 5. How much will you pay for total health check-up at one time doctor visit?
# 6. How much will you pay for todayâ€™s health checkup (if you need to pay)?
# 1. Do you have mobile phone?
# 2. Do you have access to internet connection in your mobile, computer, tab etc?
# 3. Did you use eHealth services other than PHC service before?
# 4. Do you have any kind of illness?
# 5-1. Using the PHC system would help me to better manage/maintain of my health.
# 5-2. I feel using the PHC system increases my productivity.
# 5-3. I feel PHC system is useful in my daily life.
# 5-4 Using PHC system will enhance my life effectiveness.
# 5-5. PHC system is clear and understandable to me.
# 5-6. To Interact with the PHC system does not require a lot of mental efforts /mental force/ need not to struggle with mind.
# 5-7. I did not feel hesitate to use PHC system.
# 5-8. I found receiving PHC service is easy.
# 5-9. I feel comfortable to use PHC system to share my health information.
# 5-10. The quality of output I get from PHC system is high.
# 5-11. I have no problem with the quality of the PHC systemâ€™s output.
# 5-12. The results of using the PHC system are possible/ probable to me.
# 5-13. I have no difficulty to telling others about the results of using the PHC system.
# 5-14. People who are important to me think that I should use the PHC system. (Other than family members).
# 5-15. My family members prefer to use PHC system.
# 5-16. My community people thinks that I should use PHC system.
# 5-17. Without cooperation or understanding from family, it is difficult to use PHC system for me.
# 5-18. I trust the health care services that is provided by PHC system.(health check-up, prescription)
# 5-19. I believe that the PHC system keeps its promises to protect patientâ€™s privacy.
# 5-20. If your trust about PHC system gets broken, you will stop receiving service.
# 5-21. PHC service is reliable to me.
# 5-22. I believe privacy of PHC participants is protected.
# 5-23. I believe personal information stored in PHC system is safe.
# 5-24. I believe PHC systems to keep participants information secure.
# 5-25. I consider myself very health conscious.
# 5-26. I think that I take into account health a lot in my life.
# 5-27. I think that other people pay more attention to their health than I do.
# 5-28. I want to improve my health condition.
# 5-29. I want to expand money for my health.
# 5-30. I think I will use PHC service for health check-up.
# 5-31. I  will follow PHC prescription.
# 5-32. By using PHC system I can prevent seriousness of diseases (silent killers e.g. diabetes, stroke, heart-failure, kidney-failure).
# 5-33. A specific institute exists to providing PHC health care service.
# 5-34. I have the knowledge necessary to receive the PHC system. (Explanation: It can prevent NCD diseases)
# 5-35. PHC health care service is compatible with other health care service I use.
# 5-36. I feel happy because the PHC system is used by one pre-trained nurse.
# 5-37. PHC system using saves my time.
# 5-38. PHC system is workable to prevent NCD diseases.
# 5-39. Using PHC system is a good idea.
# 5-40. I feel good to receive PHC service.
# 5-41. I intend to use PHC system in the future.
# 5-42. If PHC system is available, I will always use it.
# 5-43. It is worth to receive PHC service.
# 5-44. PHC system is a pleasant experience.
# 5-45. I spend time to know about PHC system.
# 5-46. Using PHC system causes many advantages.
# 5-47. I like to use PHC system.
# Height-2
# Weight-2
# BMI-2
# BMI Color-2
# Waist-2
# Waist Color-2
# Hip-2
# Waist/Hip Ratio-2
# Waist/Hip Ratio Color-2
# Body Temperature-2
# Body Temperature Color-2
# SpO2-2
# SpO2 Color-2
# Blood Pressure(sys)-2
# Blood Pressure(sys) Color-2
# Blood Pressure(dia)-2
# Blood Pressure(dia) Color-2
# Blood Glucose-2
# Blood Glucose Color-2
# Urinary Glucose-2
# Urinary Glucose Color-2
# Urinary Protein-2
# Urinary Protein Color-2
# Pulse Rate-2
# Pulse Rate Color-2
# Arrhythmia-2
# Arrhythmia Color-2
# Blood uric acid-2
# Blood uric acid Color-2
# Color-2
# 1. Do you have mobile phone?.1
# 2. Do you have access to internet connection in your mobile, computer, tab etc?.1
# 3. Did you use eHealth services other than PHC service before?.1
# 4. Do you have any kind of illness?.1
# 5-1. Using the PHC system would help me to better manage/maintain of my health..1
# 5-2. I feel using the PHC system increases my productivity..1
# 5-3. I feel PHC system is useful in my daily life..1
# 5-4 Using PHC system will enhance my life effectiveness..1
# 5-5. PHC system is clear and understandable to me..1
# 5-6. To Interact with the PHC system does not require a lot of mental efforts /mental force/ need not to struggle with mind..1
# 5-7. I did not feel hesitate to use PHC system..1
# 5-8. I found receiving PHC service is easy..1
# 5-9. I feel comfortable to use PHC system to share my health information..1
# 5-10. The quality of output I get from PHC system is high..1
# 5-11. I have no problem with the quality of the PHC systemâ€™s output..1
# 5-12. The results of using the PHC system are possible/ probable to me..1
# 5-13. I have no difficulty to telling others about the results of using the PHC system..1
# 5-14. People who are important to me think that I should use the PHC system. (Other than family members)..1
# 5-15. My family members prefer to use PHC system..1
# 5-16. My community people thinks that I should use PHC system..1
# 5-17. Without cooperation or understanding from family, it is difficult to use PHC system for me..1
# 5-18. I trust the health care services that is provided by PHC system.(health check-up, prescription).1
# 5-19. I believe that the PHC system keeps its promises to protect patientâ€™s privacy..1
# 5-20. If your trust about PHC system gets broken, you will stop receiving service..1
# 5-21. PHC service is reliable to me..1
# 5-22. I believe privacy of PHC participants is protected..1
# 5-23. I believe personal information stored in PHC system is safe..1
# 5-24. I believe PHC systems to keep participants information secure..1
# 5-25. I consider myself very health conscious..1
# 5-26. I think that I take into account health a lot in my life..1
# 5-27. I think that other people pay more attention to their health than I do..1
# 5-28. I want to improve my health condition..1
# 5-29. I want to expand money for my health. .1
# 5-30. I think I will use PHC service for health check-up..1
# 5-31. I  will follow PHC prescription..1
# 5-32. By using PHC system I can prevent seriousness of diseases (silent killers e.g. diabetes, stroke, heart-failure, kidney-failure)..1
# 5-33. A specific institute exists to providing PHC health care service..1
# 5-34. I have the knowledge necessary to receive the PHC system. (Explanation: It can prevent NCD diseases).1
# 5-35. PHC health care service is compatible with other health care service I use..1
# 5-36. I feel happy because the PHC system is used by one pre-trained nurse..1
# 5-37. PHC system using saves my time..1
# 5-38. PHC system is workable to prevent NCD diseases..1
# 5-39. Using PHC system is a good idea..1
# 5-40. I feel good to receive PHC service..1
# 5-41. I intend to use PHC system in the future..1
# 5-42. If PHC system is available, I will always use it..1
# 5-43. It is worth to receive PHC service..1
# 5-44. PHC system is a pleasant experience..1
# 5-45. I spend time to know about PHC system..1
# 5-46. Using PHC system causes many advantages..1
# 5-47. I like to use PHC system..1
# Height-3
# Weight-3
# BMI-3
# BMI Color
# Waist
# Waist Color
# Hip
# Waist/Hip Ratio
# Waist/Hip Ratio Color
# Body Temperature
# Body Temperature Color
# SpO2
# SpO2 Color
# Blood Pressure(sys)
# Blood Pressure(sys) Color
# Blood Pressure(dia)
# Blood Pressure(dia) Color
# Blood Glucose
# Blood Glucose Color
# Urinary Glucose
# Urinary Glucose Color
# Urinary Protein
# Urinary Protein Color
# Pulse Rate
# Pulse Rate Color
# Arrhythmia
# Arrhythmia Color
# Blood uric acid
# Blood uric acid Color
# Color
# 1. Do you have mobile phone?.2
# 2. Do you have access to internet connection in your mobile, computer, tab etc?.2
# 3. Did you use eHealth services other than PHC service before?.2
# 4. Do you have any kind of illness?.2
# 5-1. Using the PHC system would help me to better manage/maintain of my health..2
# 5-2. I feel using the PHC system increases my productivity..2
# 5-3. I feel PHC system is useful in my daily life..2
# 5-4 Using PHC system will enhance my life effectiveness..2
# 5-5. PHC system is clear and understandable to me..2
# 5-6. To Interact with the PHC system does not require a lot of mental efforts /mental force/ need not to struggle with mind..2
# 5-7. I did not feel hesitate to use PHC system..2
# 5-8. I found receiving PHC service is easy..2
# 5-9. I feel comfortable to use PHC system to share my health information..2
# 5-10. The quality of output I get from PHC system is high..2
# 5-11. I have no problem with the quality of the PHC systemâ€™s output..2
# 5-12. The results of using the PHC system are possible/ probable to me..2
# 5-13. I have no difficulty to telling others about the results of using the PHC system..2
# 5-14. People who are important to me think that I should use the PHC system. (Other than family members)..2
# 5-15. My family members prefer to use PHC system..2
# 5-16. My community people thinks that I should use PHC system..2
# 5-17. Without cooperation or understanding from family, it is difficult to use PHC system for me..2
# 5-18. I trust the health care services that is provided by PHC system.(health check-up, prescription).2
# 5-19. I believe that the PHC system keeps its promises to protect patientâ€™s privacy..2
# 5-20. If your trust about PHC system gets broken, you will stop receiving service..2
# 5-21. PHC service is reliable to me..2
# 5-22. I believe privacy of PHC participants is protected..2
# 5-23. I believe personal information stored in PHC system is safe..2
# 5-24. I believe PHC systems to keep participants information secure..2
# 5-25. I consider myself very health conscious..2
# 5-26. I think that I take into account health a lot in my life..2
# 5-27. I think that other people pay more attention to their health than I do..2
# 5-28. I want to improve my health condition..2
# 5-29. I want to expand money for my health. .2
# 5-30. I think I will use PHC service for health check-up..2
# 5-31. I  will follow PHC prescription..2
# 5-32. By using PHC system I can prevent seriousness of diseases (silent killers e.g. diabetes, stroke, heart-failure, kidney-failure)..2
# 5-33. A specific institute exists to providing PHC health care service..2
# 5-34. I have the knowledge necessary to receive the PHC system. (Explanation: It can prevent NCD diseases).2
# 5-35. PHC health care service is compatible with other health care service I use..2
# 5-36. I feel happy because the PHC system is used by one pre-trained nurse..2
# 5-37. PHC system using saves my time..2
# 5-38. PHC system is workable to prevent NCD diseases..2
# 5-39. Using PHC system is a good idea..2
# 5-40. I feel good to receive PHC service..2
# 5-41. I intend to use PHC system in the future..2
# 5-42. If PHC system is available, I will always use it..2
# 5-43. It is worth to receive PHC service..2
# 5-44. PHC system is a pleasant experience..2
# 5-45. I spend time to know about PHC system..2
# 5-46. Using PHC system causes many advantages..2
# 5-47. I like to use PHC system..2

# %%
start_p1 = columns.index('Height-1')
start_p2 = columns.index('Height-2')
start_p3 = columns.index('Height-3')

end_p1 = columns.index('Color-1')
end_p2 = columns.index('Color-2')
end_p3 = columns.index('Color')


colp1 = columns[start_p1:end_p1+1]
colp2 = columns[start_p2:end_p2+1]
colp3 = columns[start_p3:end_p3+1]

# %%
print(*colp3, sep = '\n')
# Out:
# Height-3
# Weight-3
# BMI-3
# BMI Color
# Waist
# Waist Color
# Hip
# Waist/Hip Ratio
# Waist/Hip Ratio Color
# Body Temperature
# Body Temperature Color
# SpO2
# SpO2 Color
# Blood Pressure(sys)
# Blood Pressure(sys) Color
# Blood Pressure(dia)
# Blood Pressure(dia) Color
# Blood Glucose
# Blood Glucose Color
# Urinary Glucose
# Urinary Glucose Color
# Urinary Protein
# Urinary Protein Color
# Pulse Rate
# Pulse Rate Color
# Arrhythmia
# Arrhythmia Color
# Blood uric acid
# Blood uric acid Color
# Color

# %%
data_p1 = pd.concat([cmn, data[colp1]], axis=1)
data_p2 = pd.concat([cmn, data[colp2]], axis=1)
data_p3 = pd.concat([cmn, data[colp3]], axis=1)

# %%
data_p1.isnull().mean().round(4).mul(100).sort_values(ascending=False)
# Out:
# Arrhythmia Color-1             1.08
# Arrhythmia-1                   1.08
# Color-1                        0.00
# BMI Color-1                    0.00
# Body Temperature-1             0.00
# Waist/Hip Ratio Color-1        0.00
# Waist/Hip Ratio-1              0.00
# Hip-1                          0.00
# Waist Color-1                  0.00
# Waist-1                        0.00
# BMI-1                          0.00
# SpO2-1                         0.00
# Weight-1                       0.00
# Height-1                       0.00
# Gender                         0.00
# Age                            0.00
# Bar code Id                    0.00
# Body Temperature Color-1       0.00
# SpO2 Color-1                   0.00
# Blood uric acid Color-1        0.00
# Blood Pressure(sys)-1          0.00
# Blood Pressure(sys) Color-1    0.00
# Blood Pressure(dia)-1          0.00
# Blood Pressure(dia) Color-1    0.00
# Blood Glucose-1                0.00
# Blood Glucose Color-1          0.00
# Urinary Glucose-1              0.00
# Urinary Glucose Color-1        0.00
# Urinary Protein-1              0.00
# Urinary Protein Color-1        0.00
# Pulse Rate-1                   0.00
# Pulse Rate Color-1             0.00
# Blood uric acid-1              0.00
# SL                             0.00
# dtype: float64

# %%
data_p2.isnull().mean().round(4).mul(100).sort_values(ascending=False)
# Out:
# Color-2                        0.0
# Waist-2                        0.0
# Body Temperature Color-2       0.0
# Body Temperature-2             0.0
# Waist/Hip Ratio Color-2        0.0
# Waist/Hip Ratio-2              0.0
# Hip-2                          0.0
# Waist Color-2                  0.0
# BMI Color-2                    0.0
# Blood uric acid Color-2        0.0
# BMI-2                          0.0
# Weight-2                       0.0
# Height-2                       0.0
# Gender                         0.0
# Age                            0.0
# Bar code Id                    0.0
# SpO2-2                         0.0
# SpO2 Color-2                   0.0
# Blood Pressure(sys)-2          0.0
# Blood Pressure(sys) Color-2    0.0
# Blood Pressure(dia)-2          0.0
# Blood Pressure(dia) Color-2    0.0
# Blood Glucose-2                0.0
# Blood Glucose Color-2          0.0
# Urinary Glucose-2              0.0
# Urinary Glucose Color-2        0.0
# Urinary Protein-2              0.0
# Urinary Protein Color-2        0.0
# Pulse Rate-2                   0.0
# Pulse Rate Color-2             0.0
# Arrhythmia-2                   0.0
# Arrhythmia Color-2             0.0
# Blood uric acid-2              0.0
# SL                             0.0
# dtype: float64

# %%
data_p3.isnull().mean().round(4).mul(100).sort_values(ascending=False)
# Out:
# Color                        0.0
# Waist                        0.0
# Body Temperature Color       0.0
# Body Temperature             0.0
# Waist/Hip Ratio Color        0.0
# Waist/Hip Ratio              0.0
# Hip                          0.0
# Waist Color                  0.0
# BMI Color                    0.0
# Blood uric acid Color        0.0
# BMI-3                        0.0
# Weight-3                     0.0
# Height-3                     0.0
# Gender                       0.0
# Age                          0.0
# Bar code Id                  0.0
# SpO2                         0.0
# SpO2 Color                   0.0
# Blood Pressure(sys)          0.0
# Blood Pressure(sys) Color    0.0
# Blood Pressure(dia)          0.0
# Blood Pressure(dia) Color    0.0
# Blood Glucose                0.0
# Blood Glucose Color          0.0
# Urinary Glucose              0.0
# Urinary Glucose Color        0.0
# Urinary Protein              0.0
# Urinary Protein Color        0.0
# Pulse Rate                   0.0
# Pulse Rate Color             0.0
# Arrhythmia                   0.0
# Arrhythmia Color             0.0
# Blood uric acid              0.0
# SL                           0.0
# dtype: float64

# %% [markdown]
# ### Changing string value to numerical values

# %%
print(data_p1.shape)
print(data_p2.shape)
print(data_p3.shape)
# Out:
# (93, 34)
# (93, 34)
# (93, 34)

# %%
#remove (PBS) from column
data_p1['Blood Glucose-1'] = data_p1['Blood Glucose-1'].str.rstrip(' (PBS)')
#remove (F from column
data_p1['Blood Glucose-1'] = data_p1['Blood Glucose-1'].str.rstrip(' (F')
#remove Color columns
data_p1 = data_p1.drop("BMI Color-1",1)
data_p1 = data_p1.drop("Waist Color-1",1)
data_p1 = data_p1.drop("Waist/Hip Ratio Color-1",1)
data_p1 = data_p1.drop("Body Temperature Color-1",1)
data_p1 = data_p1.drop("SpO2 Color-1",1)
data_p1 = data_p1.drop("Blood Pressure(sys) Color-1",1)
data_p1 = data_p1.drop("Blood Pressure(dia) Color-1",1)
data_p1 = data_p1.drop("Blood Glucose Color-1",1)
data_p1 = data_p1.drop("Urinary Glucose Color-1",1)
data_p1 = data_p1.drop("Urinary Protein Color-1",1)
data_p1 = data_p1.drop("Pulse Rate Color-1",1)
# data_p1 = data_p1.drop("Arrhythmia-1",1)
data_p1 = data_p1.drop("Arrhythmia Color-1",1)
data_p1 = data_p1.drop("Blood uric acid Color-1",1)
data_p1.head()
# Out:
#     SL  Bar code Id  Age   Gender  Height-1  Weight-1  BMI-1  Waist-1  Hip-1  \
# 0  215   1000236740    56  Female       145      44.2  21.02     76.0     84
# 1  116   1001011776    51  Female       158      54.6  21.87     82.0     92
# 2   39   1001014480    60    Male       165      73.6  27.03     90.0     93
# 3   52   1001014482    54    Male       170      73.0  25.26     94.0     98
# 4   75   1000898321    55    Male       164      61.2  22.75     90.0     90
#
#    Waist/Hip Ratio-1  ...  SpO2-1  Blood Pressure(sys)-1  \
# 0               0.90  ...      98                    105
# 1               0.89  ...      98                    122
# 2               0.97  ...      95                    110
# 3               0.96  ...      96                    130
# 4               1.00  ...      98                    124
#
#    Blood Pressure(dia)-1  Blood Glucose-1 Urinary Glucose-1 Urinary Protein-1  \
# 0                     70            118.8                 0                 0
# 1                     66            111.6                 0                 0
# 2                     71            102.6                 0                 0
# 3                     86            122.4                 0                 0
# 4                     83              387                 1                 0
#
#   Pulse Rate-1  Arrhythmia-1 Blood uric acid-1  Color-1
# 0          104        Normal               8.9        4
# 1           75        Normal               7.1        4
# 2           66        Normal               8.1        4
# 3           87        Normal               8.7        4
# 4           79        Normal               3.1        4
#
# [5 rows x 21 columns]

# %%
#remove color columns
data_p2 = data_p2.drop("BMI Color-2",1)
data_p2 = data_p2.drop("Waist Color-2",1)
data_p2 = data_p2.drop("Waist/Hip Ratio Color-2",1)
data_p2 = data_p2.drop("Body Temperature Color-2",1)
data_p2 = data_p2.drop("SpO2 Color-2",1)
data_p2 = data_p2.drop("Blood Pressure(sys) Color-2",1)
data_p2 = data_p2.drop("Blood Pressure(dia) Color-2",1)
data_p2 = data_p2.drop("Blood Glucose Color-2",1)
data_p2 = data_p2.drop("Urinary Glucose Color-2",1)
data_p2 = data_p2.drop("Urinary Protein Color-2",1)
data_p2 = data_p2.drop("Pulse Rate Color-2",1)
data_p2 = data_p2.drop("Arrhythmia-2",1)
data_p2 = data_p2.drop("Arrhythmia Color-2",1)
data_p2 = data_p2.drop("Blood uric acid Color-2",1)
data_p2.head()
# Out:
#     SL  Bar code Id  Age   Gender  Height-2  Weight-2  BMI-2  Waist-2  Hip-2  \
# 0  215   1000236740    56  Female       145      43.6  20.74       77     82
# 1  116   1001011776    51  Female       158      57.5  23.03       80     90
# 2   39   1001014480    60    Male       165      77.0  28.28       94     98
# 3   52   1001014482    54    Male       170      74.0  25.61       95     98
# 4   75   1000898321    55    Male       164      65.2  24.24       94     89
#
#    Waist/Hip Ratio-2  Body Temperature-2  SpO2-2  Blood Pressure(sys)-2  \
# 0               0.94               96.80      98                    112
# 1               0.89               97.16      99                    124
# 2               0.96               96.26      96                    111
# 3               0.97               96.26      97                    135
# 4               1.06               95.54      98                    129
#
#    Blood Pressure(dia)-2  Blood Glucose-2 Urinary Glucose-2 Urinary Protein-2  \
# 0                     72             95.4                 0                 0
# 1                     69            192.6                 0                 0
# 2                     73            147.6                 0                 0
# 3                     84            160.2                 0                 0
# 4                     85            345.6                 1                 0
#
#    Pulse Rate-2  Blood uric acid-2  Color-2
# 0            94                7.3        4
# 1            81                8.1        4
# 2            67                8.2        4
# 3            88                9.2        4
# 4            96                5.9        4

# %%
#remove color columns
data_p3 = data_p3.drop("BMI Color",1)
data_p3 = data_p3.drop("Waist Color",1)
data_p3 = data_p3.drop("Waist/Hip Ratio Color",1)
data_p3 = data_p3.drop("Body Temperature Color",1)
data_p3 = data_p3.drop("SpO2 Color",1)
data_p3 = data_p3.drop("Blood Pressure(sys) Color",1)
data_p3 = data_p3.drop("Blood Pressure(dia) Color",1)
data_p3 = data_p3.drop("Blood Glucose Color",1)
data_p3 = data_p3.drop("Urinary Glucose Color",1)
data_p3 = data_p3.drop("Urinary Protein Color",1)
data_p3 = data_p3.drop("Pulse Rate Color",1)
data_p3 = data_p3.drop("Arrhythmia",1)
data_p3 = data_p3.drop("Arrhythmia Color",1)
data_p3 = data_p3.drop("Blood uric acid Color",1)
data_p3.head()
# Out:
#     SL  Bar code Id  Age   Gender  Height-3  Weight-3  BMI-3  Waist  Hip  \
# 0  215   1000236740    56  Female       145      43.4  20.64     74   84
# 1  116   1001011776    51  Female       158      55.2  22.11     78   88
# 2   39   1001014480    60    Male       165      76.3  28.03     95   97
# 3   52   1001014482    54    Male       170      74.5  25.78     96   96
# 4   75   1000898321    55    Male       164      63.8  23.72     93   87
#
#    Waist/Hip Ratio  Body Temperature  SpO2  Blood Pressure(sys)  \
# 0             0.88             95.90    97                  114
# 1             0.89             95.00    99                  134
# 2             0.98             95.90    98                  123
# 3             1.00             96.44    97                  134
# 4             1.07             95.00    97                  111
#
#    Blood Pressure(dia)  Blood Glucose Urinary Glucose Urinary Protein  \
# 0                   64          111.6               0               0
# 1                   84          129.6               0               0
# 2                   83          136.8               0               0
# 3                   89          142.2               0               0
# 4                   81          324.0               1               0
#
#    Pulse Rate  Blood uric acid  Color
# 0          87              7.1      4
# 1          69              8.5      4
# 2          75              8.5      4
# 3          89              8.0      4
# 4          80              4.3      4

# %% [markdown]
# ### generating derived feature BMI and w/h

# %% [markdown]
# ### dropping composition elements of bmi

# %%
data_p1 = data_p1.drop( columns = ['Height-1', 'Weight-1', 'Waist-1', 'Hip-1'], axis=1)
data_p2 = data_p2.drop( columns = ['Height-2', 'Weight-2', 'Waist-2', 'Hip-2'], axis=1)
data_p3 = data_p3.drop( columns = ['Height-3', 'Weight-3', 'Waist', 'Hip'], axis=1)

# %%
data_p1 = data_p1.rename(columns={
    'BMI-1': 'BMI',
    'Waist/Hip Ratio-1': 'Waist/Hip',
    'Body Temperature-1': 'Body Temperature',
    'SpO2-1':'SpO2',
    'Blood Pressure(sys)-1':'Blood Pressure(sys)',
    'Blood Pressure(dia)-1':'Blood Pressure(dia)',
    'Blood Glucose-1':'Blood Glucose',
    'Urinary Glucose-1':'Urinary Glucose',
    'Urinary Protein-1':'Urinary Protein',
    'Pulse Rate-1':'Pulse Rate',
    'Blood uric acid-1':'Blood uric acid',
    'Color-1':'Color',  
    'Arrhythmia-1':'Arrhythmia',    

})
data_p1.head()
# Out:
#     SL  Bar code Id  Age   Gender    BMI  Waist/Hip  Body Temperature  SpO2  \
# 0  215   1000236740    56  Female  21.02       0.90             97.34    98
# 1  116   1001011776    51  Female  21.87       0.89             97.88    98
# 2   39   1001014480    60    Male  27.03       0.97             95.90    95
# 3   52   1001014482    54    Male  25.26       0.96             93.74    96
# 4   75   1000898321    55    Male  22.75       1.00             94.46    98
#
#    Blood Pressure(sys)  Blood Pressure(dia) Blood Glucose Urinary Glucose  \
# 0                  105                   70         118.8               0
# 1                  122                   66         111.6               0
# 2                  110                   71         102.6               0
# 3                  130                   86         122.4               0
# 4                  124                   83           387               1
#
#   Urinary Protein  Pulse Rate Arrhythmia  Blood uric acid  Color
# 0               0         104     Normal              8.9      4
# 1               0          75     Normal              7.1      4
# 2               0          66     Normal              8.1      4
# 3               0          87     Normal              8.7      4
# 4               0          79     Normal              3.1      4

# %%
data_p2 = data_p2.rename(columns={
    'BMI-2': 'BMI',
    'Waist/Hip Ratio-2': 'Waist/Hip',
    'Body Temperature-2': 'Body Temperature',
    'SpO2-2':'SpO2',
    'Blood Pressure(sys)-2':'Blood Pressure(sys)',
    'Blood Pressure(dia)-2':'Blood Pressure(dia)',
    'Blood Glucose-2':'Blood Glucose',
    'Urinary Glucose-2':'Urinary Glucose',
    'Urinary Protein-2':'Urinary Protein',
    'Pulse Rate-2':'Pulse Rate',
    'Blood uric acid-2':'Blood uric acid',
    'Color-2':'Color',    
})
data_p2.head()
# Out:
#     SL  Bar code Id  Age   Gender    BMI  Waist/Hip  Body Temperature  SpO2  \
# 0  215   1000236740    56  Female  20.74       0.94             96.80    98
# 1  116   1001011776    51  Female  23.03       0.89             97.16    99
# 2   39   1001014480    60    Male  28.28       0.96             96.26    96
# 3   52   1001014482    54    Male  25.61       0.97             96.26    97
# 4   75   1000898321    55    Male  24.24       1.06             95.54    98
#
#    Blood Pressure(sys)  Blood Pressure(dia)  Blood Glucose Urinary Glucose  \
# 0                  112                   72           95.4               0
# 1                  124                   69          192.6               0
# 2                  111                   73          147.6               0
# 3                  135                   84          160.2               0
# 4                  129                   85          345.6               1
#
#   Urinary Protein  Pulse Rate  Blood uric acid  Color
# 0               0          94              7.3      4
# 1               0          81              8.1      4
# 2               0          67              8.2      4
# 3               0          88              9.2      4
# 4               0          96              5.9      4

# %%
data_p3 = data_p3.rename(columns={
    'BMI-3': 'BMI',  
})
data_p3.head()
# Out:
#     SL  Bar code Id  Age   Gender    BMI  Waist/Hip Ratio  Body Temperature  \
# 0  215   1000236740    56  Female  20.64             0.88             95.90
# 1  116   1001011776    51  Female  22.11             0.89             95.00
# 2   39   1001014480    60    Male  28.03             0.98             95.90
# 3   52   1001014482    54    Male  25.78             1.00             96.44
# 4   75   1000898321    55    Male  23.72             1.07             95.00
#
#    SpO2  Blood Pressure(sys)  Blood Pressure(dia)  Blood Glucose  \
# 0    97                  114                   64          111.6
# 1    99                  134                   84          129.6
# 2    98                  123                   83          136.8
# 3    97                  134                   89          142.2
# 4    97                  111                   81          324.0
#
#   Urinary Glucose Urinary Protein  Pulse Rate  Blood uric acid  Color
# 0               0               0          87              7.1      4
# 1               0               0          69              8.5      4
# 2               0               0          75              8.5      4
# 3               0               0          89              8.0      4
# 4               1               0          80              4.3      4

# %%
data_p3.Color
# Out:
# 0     4
# 1     4
# 2     4
# 3     4
# 4     4
#      ..
# 88    2
# 89    2
# 90    2
# 91    1
# 92    1
# Name: Color, Length: 93, dtype: int64

# %% [markdown]
# ### saving cleanded data

# %%
data_p1.to_csv('../dataset/p1_cleaned_data_full.csv')
data_p1 = data_p1.drop("Arrhythmia",1)
data_p1.to_csv('../dataset/p1_cleaned_data.csv')
data_p2.to_csv('../dataset/p2_cleaned_data.csv')
data_p3.to_csv('../dataset/p3_cleaned_data.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-23fe50f5d2c9> in <module>
#       1 data_p1.to_csv('../dataset/p1_cleaned_data_full.csv')
# ----> 2 data_p1 = data_p1.drop("Arrhythmia-1",1)
#       3 data_p1.to_csv('../dataset/p1_cleaned_data.csv')
#       4 data_p2.to_csv('../dataset/p2_cleaned_data.csv')
#       5 data_p3.to_csv('../dataset/p3_cleaned_data.csv')
#
# O:\Technical\Editors\Anaconda\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# O:\Technical\Editors\Anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# O:\Technical\Editors\Anaconda\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# O:\Technical\Editors\Anaconda\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['Arrhythmia-1'] not found in axis"

# %%
# correlation = df.corr()

# # constructing a heatmap to undestand the correlation between the columns
# plt.figure(figsize=(15,15))
# sns.heatmap(correlation, cbar=True, square=True, fmt='.1f', annot=True, annot_kws={'size':12}, cmap = 'OrRd')
